# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/esaruhann/DS4SDGs/blob/Data_Manupilation/02-DS4SDGS-Exploratory%20Data%20Analysis_v0.3.2.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Learning Objectives <a class="anchor" id="zero"></a>
#
# - Load a CSV dataset with proper character encoding for use in a Colab environment.
#
# - Be able to identify inconsistencies in data entry and handle missing values by either dropping or filling them through an automated workflow.
#
# - Understand the purpose of scaling and normalization to enable numeric analysis.
#
# - Understand the DataFrame and Series formats to efficiently conduct data manipulation for analysis.
#
# - Be able to utilize Pandas, the most popular Python package for data analysis, to create, read, and write files, as well as for indexing, selecting, and assigning values.
#
# - Create basic data visualizations using Seaborn, including line charts, bar charts, heatmaps, scatter plots, and histograms for distribution.
# <br>

# %% [markdown]
# # 1. Introduction to Exploratory Data Analysis (EDA) <a class="anchor" id="one"></a>

# %% [markdown]
# ## 1.1 EDA Definition <a class="anchor" id="one-one"></a>

# %% [markdown]
# Exploratory Data Analysis (EDA) is the initial step in analyzing your dataset and a crucial part of preparing your data before applying a predictive model. It begins with understanding the types of variables in your dataset and then involves performing both univariate and bivariate analyses using visualization and statistical methods. Once this process is completed, you will have a clearer understanding of your data and be able to apply that knowledge to feature engineering and pre-processing activities. These steps are prerequisites for modeling.
#
# When it comes to the question, "How do you perform EDA?", there is no definitive answer, as it largely depends on the dataset you are working with. There is no single method or universally accepted approach to conducting EDA.

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# What is Exploratory Data Analysis in Data Science?
# ```
# * [ChatGPT Tutor Response](https://chat.openai.com/share/163bdda3-da35-4b5f-b637-99d215ae82e4)
#
#
# * [Bard Tutor Response](https://g.co/bard/share/6e9c3e68cccf)

# %% [markdown]
# ## 1.2 EDA Benefits in Data Science <a class="anchor" id="one-two"></a>

# %% [markdown]
# Exploratory Data Analysis (EDA) is an essential process in preparing for machine learning projects, as it helps to address several critical questions:
#
# * How can you ensure that you are ready to apply machine learning algorithms to your project?
# * What are the best strategies for selecting the most appropriate algorithms for your specific dataset?
# * How should you identify and define the feature variables that could be utilized for machine learning?
# <br>
# <br>
# EDA offers considerable value to data science projects by enabling a closer approach to certainty that future results will be valid, properly interpreted, and relevant to the intended business context. This level of confidence is attainable only after thoroughly validating the raw data and checking for outliers, which ensures the absence of collection errors in the data set. Beyond error-checking, EDA also uncovers insights that may not have been immediately apparent or considered significant to business stakeholders, thereby allowing data scientists to develop a clear understanding of the business requirements.
# <br>
# <br>
# One of the core functions of EDA is to define and refine the selection of feature variables that will be utilized for machine learning. By thoroughly analyzing the given data set, data scientists often realize that their initial choices of features may not serve the intended purpose. As such, they may have to revisit the feature engineering phase. Upon completing the EDA stage, data scientists will have solidified the feature set needed to pursue both supervised and unsupervised machine learning, aligning the analysis with the specific goals and needs of the project.

# %% [markdown]
# ![MicrosoftTeams-image (6).png](data:image/png;base64,...)
# <br>
# <center><b>SDG AI Lab Standard Framework for a Data Science Project</b></center>

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# What are the benefits of Exploratory data analysis in the context of machine learning and Data science in general?
# ```
# * [ChatGPT Tutor Response](https://chat.openai.com/share/53ef8246-55cc-451f-90fd-e7407d1aa2f1)

# %% [markdown]
# ## 1.3 EDA Key Steps for a Data Science Project <a class="anchor" id="one-three"></a>
#
# The EDA process can be broad and flexible with varying steps based on specific types of data and questions we are trying to answer. Below, we have provided a general summary of some common EDA steps that are necessary in a data science project:
#
# - Check the shape of the data frame by a total number of entries and column types.
#
# - Check any null values or duplicate entries
#
# - Plot distribution of numeric data, univariate and pairwise joint distribution
#
# - Plot count distribution of categorical data
#
# - Analyze time series of numeric data by daily, monthly and yearly frequencies
# <br>

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# What are the key steps of Exploratory Data Analysis  for  a Data Science Project? Give the response in a list format/
# ```
# * [ChatGPT Tutor Response](https://chat.openai.com/share/680fcd9c-dd44-4626-ba36-6f432def94bc)
#
#
# * [Bard Tutor Response](https://g.co/bard/share/2c2458039102)

# %% [markdown]
# ## 1.4 Introduction to Python Libraries for EDA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In the context of exploratory data analysis (EDA), there are a few key Python packages that allow us to explore and analyze our data: These include, but are not limited to, Pandas, NumPy, Matplotlib, and Seaborn.
#
# What are these libraries and what are their main functions?
# <br>
# <br>
# ### 1.4.1 Pandas Library
# Pandas is a freely available library, distributed under the BSD license, that provides efficient and user-friendly data structures and tools for data analysis, specifically designed for the Python programming language. It is built on top of two core Python libraries: Matplotlib for data visualization and NumPy for mathematical operations, which we will introduce next.
#
# <br> Pandas library offers the following functionalities: Data cleaning, data transformation, data analysis, data visualization, handling missing data, and more.
#
# **Key Features of Pandas:**
#
# * DataFrame object for data manipulation with integrated indexing.
# * Tools for reading and writing data between in-memory data structures and different file formats.
# * Data alignment and integrated handling of missing data.
# * Reshaping and pivoting of data sets.
# * Label-based slicing, fancy indexing, and subsetting of large data sets.
#
#
# If you're curious and want to get a glimpse of what Pandas Library has to offer before we delve into it in the upcoming sections, please check out the official online [Pandas resource here.](https://pandas.pydata.org/)
# <br>
# <br>
#
# ### 1.4.2 Numpy Library
#
# NumPy, short for 'Numerical Python,' provides support for large, multi-dimensional arrays and matrices. It also includes a broad range of high-level mathematical functions to perform operations on these arrays. NumPy serves as the foundation for numerical computing in Python.
#
# **Key Features of Numpy:**
#
# * Provides a robust N-dimensional array object, serving as an efficient multi-dimensional container for data of varying types.
# * Offers sophisticated functions for element-wise computations and broadcasting.
# * Includes tools for integrating code written in C, C++, and Fortran.
# * Equipped with valuable features for linear algebra, Fourier transformations, and generating random numbers.
#
# For more information on Numpy library, please check out the [official package documentation here](https://numpy.org/).
#
# <br>
#
# ### 1.4.3 Matplotlib Library
# Matplotlib is a powerful and comprehensive Phyton visualization library that is built on NumPy arrays. It provides the following key features:
#
# **Key Features of Matplotlib:**
#
# * Creating static, animated, and interactive visualizations in Python.
# * Generating plots, histograms, power spectra, bar charts, error charts, scatterplots, etc., with just a few lines of code.
# * For simple plots, the pyplot module provides a MATLAB-like interface.
# * For complex figures with subplots, insets, and other components, it offers an object-oriented API.
#
# More information on Matplotlib library can be found via [this link](https://matplotlib.org/)
#
# <br>
# <br>
#
# ### 1.4.4 Seaborn Library
#
# Seaborn is a statistical data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. It's often used to make statistical graphics more readable and to create more complex visualizations that would be tedious to create in Matplotlib.
#
# **Key Features:**
#
# * Support for numpy and pandas data structures.
# * Built-in themes for styling matplotlib graphics.
# * Tools for choosing color palettes to make beautiful plots that reveal patterns in your data.
# * Functions to visualize univariate and bivariate distributions and to compare them between subsets of data.
# * Tools to fit and visualize linear regression models for different kinds of independent and dependent variables.

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# What are the most common Python packages that allow data scientist to explore and analyse datasets. What features do these packages possess and what is their function?
# ```
# * [ChatGPT Tutor Response](https://chat.openai.com/share/6193fe1b-9389-4da0-9a5b-f5b1a09df571)
#
#
# * [Bard Tutor Response](https://g.co/bard/share/a8af56982fcd)

# %% [markdown]
# **Key Point:**
#
# By integrating the four libraries above into your EDA process, you can perform efficient and effective data analysis and visualizations over any dataset of interest. After completing this chapter, you will know how to use these libraries for your data exploratory tasks.
#
# Talking about data exploration, let's load in our dataset and start exploring in the next section.

# %% [markdown]
# # 2. Loading and Exploring Data (Data Overview)
#
# Before we dive into loading our dataset for analysis and visualization, it's crucial to first understand how the data is structured and represented in Python using Pandas DataFrame and Series. This foundational knowledge will facilitate effective data manipulation and exploration as we proceed.

# %% [markdown]
# ### 2.1 Introduction to Pandas DataFrame and Series
#
#
#
# A **Series** object in the pandas library is defined in the [documentation](https://pandas.pydata.org/docs/reference/api/pandas.Series.html) as a "one-dimensional ndarray with axis labels (including time series)."
# - A Series object can be created from an array-like object (e.g., Python list, NumPy array), an iterable, a dict or a scalar value.
# - Math operators (+, -, /, *, **) can be used to combine two Series objects regardless of their size.
#
# A **DataFrame** object, on the other hand, is [defined](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) as a "two-dimensional, size-mutable, potentially heterogeneous tabular data."
# - A DataFrame object can be created from an n-dimensional array (structured or homogeneous), an iterable or a dict.

# %% [markdown]
# **Create Pandas Series and DataFrame**
#
# To create a Pandas Series or DataFrame, or perform any operation using the library, we need to import it. This is true for any other python library.
#
# So, let's import Pandas and demonstrate how to create a simple Pandas Series and DataFrame.

# %%
# Import the pandas library and assign it the alias pd
import pandas as pd

# List of ages
ages_list = [25, 30, 35, 40, 21, 21, 19]

# List of random life expectancies
life_expectancy_list = [80, 90, 74, 40, 65, 55, 58]

# List of countries
country_list = ['Cameroon', 'Turkiye', 'Japan']

# Create a pandas Series from the list
series_1 = pd.Series(data=ages_list)
series_2 = pd.Series(data=life_expectancy_list)
series_3 = pd.Series(data=country_list)

# %%
#P erform basic operations with Pandas Series

# Addition
print(f"Addition:\n{series_1 + series_2}")

# Subtraction
print(f"\nSubstraction:\n{series_2 - series_1}")

# Multiplication
print(f"\nMultiplication:\n{series_1 * series_2}")

# Division
print(f"\nDivision:\n{series_2 / series_1}")

# Exponent
print(f"\nExponent:\n{series_1 ** series_2}")
# Out:
# Addition:
# 0    105
# 1    120
# 2    109
# 3     80
# 4     86
# 5     76
# 6     77
# dtype: int64
#
# Substraction:
# 0    55
# 1    60
# 2    39
# 3     0
# 4    44
# 5    34
# 6    39
# dtype: int64
#
# Multiplication:
# 0    2000
# 1    2700
# 2    2590
# 3    1600
# 4    1365
# 5    1155
# 6    1102
# dtype: int64
#
# Division:
# 0    3.200000
# 1    3.000000
# 2    2.114286
# 3    1.000000
# 4    3.095238
# 5    2.619048
# 6    3.052632
# dtype: float64
#
# Exponent:
# 0    5918522610932723073
# 1                      0
# 2   -8888253075999141015
# 3                      0
# 4   -6602116611812085995
# 5   -1495954384722408611
# 6   -9197838518961310135
# dtype: int64

# %% [markdown]
# **Creating a Dataframe**
#
# Here's a basic example on how to create a simple Pandas DataFrame.

# %%
# Import the pandas library
import pandas as pd

# Create a dictionary of data
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Dave'],
    'Age': [25, 31, 35, 19],
    'City': ['New York', 'Chicago', 'Los Angeles', 'Seattle']
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   31      Chicago
# 2  Charlie   35  Los Angeles
# 3     Dave   19      Seattle

# %% [markdown]
# <p align="center">
#   <img src="https://i.ibb.co/wJ7XNCg/dataframe.jpg" />
# </p>

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# What is the difference between Pandas Series and Pandas Dataframe. Give clear examples to demonstrate their differences.
# ```
#
# * [ChatGPT Tutor Response](https://chat.openai.com/share/d97e74b2-f48d-4bfa-aa73-b996fbd69fe1)
#
#
# * [Bard Tutor Response](https://g.co/bard/share/e7db3fa70191)

# %% [markdown]
# ### 2.2 Overview of Real-World Dataset <a class="anchor" id="three-two"></a>
#
# The dataset we'll be working with in this EDA course is a CSV file containing life expectancy trends for different countries, based on historical records from approximately the year 1700 up to 1950.
#
# You can access the dataset clicking the [github link here](https://github.com/open-numbers/ddf--gapminder--life_expectancy_historic).
#
# How do we make the data accessible on Google Colab? In **section 2.2.3 Access External files - Upload Files**, we covered several ways to load files to Google Colab. You can download or clone the github repository. Then upload the file named `ddf--datapoints--life_expectancy_at_birth--by--area--year.csv` to Google Colab, as shown in the previous course.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# >Image from [Life Expectancy](https://ourworldindata.org/life-expectancy) by by Max Roser, Esteban Ortiz-Ospina and Hannah Ritchie

# %% [markdown]
# ### 2.3 Loading CSV Dataset into a Pandas DataFrame

# %% [markdown]
# Now that we have an idea of the dataset we will be exploring and analyzing, it's time to load the data into our notebook and get started.
# To read the csv dataset file, we will use the function `pd.read_csv()`, specifying the file path of our dataset as an argument.
#
# The cell shows us how to achieve this.

# %%
# absolute directory
df = pd.read_csv("ddf--datapoints--life_expectancy_at_birth--by--area--year.csv")

# %% [markdown]
# If the data file (e.g "ddf--datapoints--life_expectancy_at_birth--by--area--year.csv") and the code (e.g. your jupyter notebook) are saved in the same directory, there is no need to add the full path when using the pd.read_csv command. For example, instead of using **'/path/of/the/file/ddf--datapoints--life_expectancy_at_birth--by--area--year.csv'**,(as in the cell below), you may use **"ddf--datapoints--life_expectancy_at_birth--by--area--year.csv"** directly (as in the cell above).

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive to Colab
drive.mount('/content/drive')

basedir = "/content/drive/MyDrive/SDG_AI_LAB_UNDP/DS4SDGS/data"

# Read CSV file into DataFrame. Replace with your actual file path
df = pd.read_csv( basedir + '/life_expectancy/life_expectancy.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# According to application requirements, absolute or relative paths can be used:

# %% [markdown]
# > **Absolute Paths**
# > - Always starts from the root path
# > - Drive + {folder(s)} + {file}. e.g. C:/Projects/Data/file.csv
#
# > **Relative Paths**
# > - It's the path with respect to the current directory
# > - {folder(s)} + {file}. e.g. /sdgailab/HOME

# %% [markdown]
# **Read other kinds of Data**
#
# While .csv files are commonly used, other kinds of data can also be loaded using the Pandas library. Common filetypes one may work with are outputs from Excel, or files with .JSON (Jason), .XML or .PKL (Pickle) extensions. For further information on additional filetypes pandas can handle, please see their [Reference](https://pandas.pydata.org/docs/reference/io.html) page.

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# **Prompt**
# ```
# How to load .JSON, .XML or .PKL dataset files in python?
# ```
#
# [ChatGPT Tutor Response](https://chat.openai.com/share/f780b559-c041-4aac-8575-d6f347b63c12)
#
# [Bard Tutor Response](https://g.co/bard/share/96f8ef5ef8a1)
#
# <br>
#
# **Try out Prompt**
#
# ```
# What is the are the advantages and disadvantages of storing data in .JSON, .XML or .PKL file format
# ```

# %% [markdown]
# ### 2.4 Exploring Dataset DataFrame

# %% [markdown]
# Having successfully loaded our dataset, it's time to explore its contents to better understand the nature and structure of the data.
#
# Pandas provides a wide array of powerful functions that are essential for gaining insights into the intrinsic details of our dataset.
#
# Let’s use these functions to thoroughly analyze and understand our dataset:

# %% [markdown]
# #### **2.4.1. df.head(): Quick Look into Dataset Rows**
#
#  The `df.head()` function in pandas allows
# you to have a quick look at the first few rows of a DataFrame.
# If you want to see a different number of rows, you can pass that number as an argument to `df.head()`. For example, `df.head(10)` will show the first 10 rows.

# %%
print(df.head()) # Show first five rows by default

print(df.head(10)) # Show first 10 rows
# Out:
#           area  year  life_expectancy_at_birth
# 0  afghanistan  1800                 28.211000
# 1  afghanistan  1917                 27.012140
# 2  afghanistan  1918                  7.045063
# 3  afghanistan  1919                 26.991647
# 4  afghanistan  1950                 26.674000
#           area  year  life_expectancy_at_birth
# 0  afghanistan  1800                 28.211000
# 1  afghanistan  1917                 27.012140
# 2  afghanistan  1918                  7.045063
# 3  afghanistan  1919                 26.991647
# 4  afghanistan  1950                 26.674000
# 5  afghanistan  1951                 26.932000
# 6  afghanistan  1952                 27.448000
# 7  afghanistan  1953                 27.964000
# 8  afghanistan  1954                 28.480000
# 9  afghanistan  1955                 28.995000

# %% [markdown]
# #### **2.4.2. display.max_columns / display.max_rows: Display Dataset**

# %% [markdown]
# In Pandas, `pd.options.display.max_columns` and `pd.options.display.max_rows` are options for setting the maximum number of columns and rows displayed when you output a DataFrame. This is particularly useful when working with large DataFrames, as it allows you to control how much of the DataFrame is printed to the console, making it easier to read and understand the data.

# %%
# In this example, the maximum number of columns
# displayed when printing a DataFrame is set to 50.

pd.set_option('display.max_columns', 50)

# %%
# set maximum number of rows displayed when printing a DataFrame is set to 100.
import pandas as pd
pd.set_option('display.max_rows', 100)

# %%
print(df)

# %%
# display all the columns or rows by setting the value to `None`

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### **2.4.3 df.shape: Dimension of DataFrame**
#
#  Returns a tuple representing the dimensionality of the DataFrame. The first tuple element is the number of rows and the second element is the number of columns.
#
# For example, running the cell below, indicates our dataset has **35195** rows and **3** columns.

# %%
print(df.shape)
# Out:
# (35195, 3)

# %% [markdown]
# #### **2.4.4. df.info(): Quick Overview of DataFrame**
# Provides a quick overview of the DataFrame. It is especially useful for larger datasets. When you call this function, it prints information about the DataFrame, including the number of entries (rows), number of columns, names of all the columns, the number of non-null values in each column, the data type of each column, and the memory usage of the DataFrame.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35195 entries, 0 to 35194
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   area                      35195 non-null  object
#  1   year                      35195 non-null  int64
#  2   life_expectancy_at_birth  35195 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 825.0+ KB
# None

# %% [markdown]
# #### **2.4.5 Accessing Columns and Rows of a Data Frame  <a class="anchor" id="three-one-three"></a>**
#
# After we have the data resource, it is time to start processing the dataset for further analysis. The first basic concept we hope to introduce is how to access the columns and rows.

# %%
# select first column:

df["area"]
# Out:
# 0        afghanistan
# 1        afghanistan
# 2        afghanistan
# 3        afghanistan
# 4        afghanistan
#             ...
# 35190       zimbabwe
# 35191       zimbabwe
# 35192       zimbabwe
# 35193       zimbabwe
# 35194       zimbabwe
# Name: area, Length: 35195, dtype: object

# %%
# select multiple columns:

df[["area" , "year"]]
# Out:
#               area  year
# 0      afghanistan  1800
# 1      afghanistan  1917
# 2      afghanistan  1918
# 3      afghanistan  1919
# 4      afghanistan  1950
# ...            ...   ...
# 35190     zimbabwe  2095
# 35191     zimbabwe  2096
# 35192     zimbabwe  2097
# 35193     zimbabwe  2098
# 35194     zimbabwe  2099
#
# [35195 rows x 2 columns]

# %%
# select first row:

df.iloc[0,:]
# Out:
# area                        afghanistan
# year                               1800
# life_expectancy_at_birth         28.211
# Name: 0, dtype: object

# %%
# select multiple rows:

df.iloc[[1,3],:]
# Out:
#           area  year  life_expectancy_at_birth
# 1  afghanistan  1917                 27.012140
# 3  afghanistan  1919                 26.991647

# %% [markdown]
# **Using `loc[]` function of the Dataframe**
#
# The difference between `loc[]` vs `iloc[]` is how you select rows and columns from a pandas DataFrame:
#
# * `loc[]` is used to select rows and columns by Names/Labels
# * `iloc[]` is used to select rows and columns by Integer Index/Position. zero based index position.
#
# One of the main advantages of pandas DataFrame is its ease of use. You can see this yourself when you use the `loc[]` or `iloc[]`methods to select or filter rows or columns. These are some of the most commonly used attributes in pandas DataFrame.

# %%
print("Given Dataframe :\n", df)

print("\nIterating over rows using loc function :\n")

# iterate through each row and select
# 'area' and 'year' column respectively.
for i in range(len(df)):
    print(df.loc[i, "area"], df.loc[i, "year"])

    if i%10 == 0:
      break
# Out:
# Given Dataframe :
#                area  year  life_expectancy_at_birth
# 0      afghanistan  1800                 28.211000
# 1      afghanistan  1917                 27.012140
# 2      afghanistan  1918                  7.045063
# 3      afghanistan  1919                 26.991647
# 4      afghanistan  1950                 26.674000
# ...            ...   ...                       ...
# 35190     zimbabwe  2095                 80.468000
# 35191     zimbabwe  2096                 80.617000
# 35192     zimbabwe  2097                 80.765000
# 35193     zimbabwe  2098                 80.911000
# 35194     zimbabwe  2099                 81.056000
#
# [35195 rows x 3 columns]
#
# Iterating over rows using loc function :
#
# afghanistan 1800

# %% [markdown]
# **Using iterrows() method of the Dataframe**
#
# Pandas `DataFrame.iterrows()` is used to iterate over DataFrame rows. This returns (index, Series) where the index is an index of the Row and Series is data or content of each row.

# %%
print("\nIterating over rows using iterrows() method :\n")

counter = 0

# iterate through each row and select
# 'area' and 'year' column respectively.
for index, row in df.iterrows():

  #print only first 10 rows
    if counter < 10:
        print(row["area"], row["year"])
        counter += 1
    else:
        break
# Out:
# Iterating over rows using iterrows() method :
#
# afghanistan 1800
# afghanistan 1917
# afghanistan 1918
# afghanistan 1919
# afghanistan 1950
# afghanistan 1951
# afghanistan 1952
# afghanistan 1953
# afghanistan 1954
# afghanistan 1955

# %% [markdown]
# **Using itertuples() method of the Dataframe**
#
# The `itertuples()` method of a pandas DataFrame is one of the most commonly used methods to iterate over rows, as it returns all DataFrame elements as an iterator containing a tuple for each row.
#
# The main difference between this method and `iterrows()` is that `itertuples()` is faster. Additionally, it preserves the data type of each column, unlike iterrows(), which returns a Series for each row and does not preserve column data types. The itertuples() method returns a tuple where the first value is the index number of the row, and the remaining values are the values for each column

# %%
print("\nIterating over rows using itertuples() method :\n")

counter = 0
# iterate through each row and select
# 'area' and 'year' column respectively.
for row in df.itertuples(index=True, name='Pandas'):
    if counter < 10:
        print(getattr(row, "area"), getattr(row, "year"))
        counter += 1
    else:
        break
# Out:
# Iterating over rows using itertuples() method :
#
# afghanistan 1800
# afghanistan 1917
# afghanistan 1918
# afghanistan 1919
# afghanistan 1950
# afghanistan 1951
# afghanistan 1952
# afghanistan 1953
# afghanistan 1954
# afghanistan 1955

# %% [markdown]
# # 3. Statistical Description of Dataset
#
# Performing basic statistical analysis of our dataset is a crucial step in the EDA process, as it provides an initial understanding of the data's characteristics and structure. It helps identify trends, patterns, outliers, and potential anomalies, which could significantly influence further data analysis or modeling. Furthermore, these analyses can reveal data distribution, central tendencies (mean, median), dispersion (range, variance, standard deviation), and correlations between variables.
# <br>
# The Pandas library offers a set of simple functions for statistical analysis to help us better understand our dataset.

# %% [markdown]
# ### **3.1 df.describe(): Quick Statistical Summary**
#
# Generates descriptive statistics of the dataset DataFrame. By default, the `describe()` method returns the following statistics for each numerical column:
#
# * ***count:*** Number of non-null observations
# mean: Mean (average) of the values in the column
# * **std:** Standard deviation, which measures the spread of the values in the column
# * **min:** Minimum value in the column
# * **25%:** First quartile or 25th percentile
# * **50%:** Second quartile or median or 50th percentile
# * **75%:** Third quartile or 75th percentile
# * **max:** Maximum value in the column

# %%
df.describe()
# Out:
#                year  life_expectancy_at_birth
# count  35195.000000              35195.000000
# mean    2003.637022                 66.529435
# std       70.198287                 17.238859
# min     1541.000000                  1.000000
# 25%     1968.000000                 56.031000
# 50%     2012.000000                 70.909000
# 75%     2056.000000                 79.666000
# max     2099.000000                 95.645000

# %% [markdown]
# ## 3.2 More on Descriptive Statistics
#
# To compute more descriptive statistical measures on your dataset, Pandas provides simple functions to achieve this.
#
# Let's perform several descriptive statistical analysis on our dataset, specifically, on the life expectancy column as indicated in the next few cells below:

# %% [markdown]
# ### 3.2.1. mean():
#
# Returns the mean of the values for the requested axis.

# %%
print(df['life_expectancy_at_birth'].mean())
# Out:
# 66.52943499881617

# %% [markdown]
# ### 3.2.2.median(): Returns the median of the values over the requested axis.

# %%
print(df['life_expectancy_at_birth'].median())
# Out:
# 70.909

# %% [markdown]
# ### 3.2.3. mode(): Returns the mode of a dataset.

# %%
print(df['life_expectancy_at_birth'].mode())
# Out:
# 0    32.0
# Name: life_expectancy_at_birth, dtype: float64

# %% [markdown]
# ### 3.2.4. sum(): Returns the sum of the values for the requested axis.

# %%
print(df['life_expectancy_at_birth'].sum())
# Out:
# 2341503.464783335

# %% [markdown]
# ### 3.2.5. min(): Returns the minimum of the values for the requested axis.

# %%
print(df['life_expectancy_at_birth'].min())
# Out:
# 1.0

# %% [markdown]
# ### 3.2.6. max(): Returns the maximum of the values for the requested axis.

# %%
print(df['life_expectancy_at_birth'].max())
# Out:
# 95.645

# %% [markdown]
# ### 3.2.7. var(): Returns the variance of the values over the requested axis.

# %%
print(df['life_expectancy_at_birth'].var())
# Out:
# 297.1782668840411

# %% [markdown]
# ### 3.2.8. std(): Returns the standard deviation of the values over the requested axis.

# %%
print(df['life_expectancy_at_birth'].std())
# Out:
# 17.238859210633432

# %% [markdown]
# ### 3.2.9. quantile(): Returns the quantile(s) of the values over the requested axis.

# %%
print(df['life_expectancy_at_birth'].quantile(0.25))
# Out:
# 56.031

# %% [markdown]
# ### 3.2.10. count(): Returns the number of non-NA/null values in the DataFrame.

# %%
print(df['life_expectancy_at_birth'].count())
# Out:
# 35195

# %% [markdown]
# ### 3.2.11. df.value_counts():
# Returns a Series containing unique values as its index and frequencies as its values, ordered count in descending order.
#
# For example, we might be interested in the number of times of each country appears in our dataset. This can help us to understand the distribution of our dataset with respect to countries as seen in the cell below.

# %%
print(df['area'].value_counts()) # United Kingdown has the highest number of entries 559
# Out:
# united_kingdom     559
# iceland            365
# norway             365
# denmark            365
# france             360
#                   ...
# channel_islands    150
# taiwan             108
# greenland           54
# aland               10
# tokelau              1
# Name: area, Length: 204, dtype: int64

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# **Prompt**
# ```
# Given a dataset, what are the Pandas functions that we can use to statistically describe the dataset. Illustrate this using a toy dataset.
# ```
#
#
# [ChatGPT Tutor Response](https://chat.openai.com/share/0daf65b1-94fa-421a-9637-e1ea3e41e584)
#
# * Copy and paste the prompt above in your  [BARD](https://bard.google.com/) interface to see what response BARD machine Tutor will generate for you.
#
# <br>

# %% [markdown]
# **Key Point:**
#
# Now that we've explored our dataset and got a handle on its descriptive statistics, it's time to roll up our sleeves and dive into the world of data cleaning. In other words, let's tidy up our dataset.

# %% [markdown]
# # 4. Data Cleaning

# %% [markdown]
# Data cleaning is a crucial step in any data analysis process. It involves preparing and "cleaning" the data to ensure it's accurate, consistent, and usable. The steps outlined below describe key aspects of data cleaning.
#
# - Identify missing values and outliers
# - Check for overall plausibility and errors such as typos
# - Identify highly correlated variables, variables with nearly no variance
# - Identify variables with strange names or values
# - Check variable classes such as characters and factors
# - Rename variables or values, especially when there are a large number of them that are of particular interest
# - Check some overall patterns in statistical and numerical summaries
#
# The Pandas functions described in the previous sections can be used to understand the data and hence, apply appropriate data cleaning steps.
# <br>
#
# **Key Point**: Data cleaning is not just about applying functions. It's about understanding the context, knowing why you're making the choices you're making, and being aware of the trade-off. In the next few cells, you'll learn the main Pandas functions used in the data cleaning process. Depending on the dataset you are working with, you can select the appropriate functions.

# %% [markdown]
# ## 4.1. Handling Missing Values

# %% [markdown]
# Missing data is actually the most common occurrence of dirty data. Imagine trying to do a customer segmentation analysis, but 50% of the data have no address on record. It would be hard or impossible to do your analysis since the analysis would be bias in showing no customers in certain areas. That is the reason why checking the missing data in our dataset is quite important.
#
# Blank space, None, NaN, and NaT are the general types of missing data. Learning how to check the missing data is provided below.

# %% [markdown]
# ### 4.1.1 df.isna() and df.isnull(): Check for Missing Values.
#
#
#
# **`df.isna()`** returns a DataFrame of the same shape as the original, but with True in the location of elements that are NaN or None, and False elsewhere.
#
# **`df.isnull()`** returns a DataFrame where each cell is either True or False depending on whether that cell's original value is missing (i.e., NaN in numerical arrays, None or NaN in object arrays, NaT in datetimelike). So if a cell's value is missing, df.isnull() will return True for that cell; otherwise, it will return False.

# %%
# our sample data set has no missing values
df.isna()
# Out:
#         area   year  life_expectancy_at_birth
# 0      False  False                     False
# 1      False  False                     False
# 2      False  False                     False
# 3      False  False                     False
# 4      False  False                     False
# ...      ...    ...                       ...
# 35190  False  False                     False
# 35191  False  False                     False
# 35192  False  False                     False
# 35193  False  False                     False
# 35194  False  False                     False
#
# [35195 rows x 3 columns]

# %%
# check if dataset has null values
print(df.isnull())
# Out:
#         area   year  life_expectancy_at_birth
# 0      False  False                     False
# 1      False  False                     False
# 2      False  False                     False
# 3      False  False                     False
# 4      False  False                     False
# ...      ...    ...                       ...
# 35190  False  False                     False
# 35191  False  False                     False
# 35192  False  False                     False
# 35193  False  False                     False
# 35194  False  False                     False
#
# [35195 rows x 3 columns]

# %%
# print the number of missing values per column
print(df.isnull().sum())
# Out:
# area                        0
# year                        0
# life_expectancy_at_birth    0
# dtype: int64

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# **Prompt**
# ```
# One of the key steps in exploratory data analysis  is data cleaning, which involved handling missing values, and Pandas provides functions such as df.isna() and df.isnull(). Write a python code that shows how these functions can be used in handling missing values in a example dataset.
# ```
#
#
# [ChatGPT Tutor Response](https://chat.openai.com/share/95356b3d-dc19-44db-89c3-1b2dedf29264)
#
# [Bard Tutor Response](https://g.co/bard/share/d5957f503553)
#
# <br>

# %% [markdown]
# ### 4.1.2. df.dropna(): Remove Missing Values.
#
# `df.dropna()` analyses and drops/removes missing values from the dataset DataFrame rows and columns np.nan/pd.NaT (Null/None) are considered as missing values.

# %%
df = df.dropna()  # Removes rows with missing values

# %% [markdown]
# ### 4.1.3. df.drop(): *Remove* Specified Rows/Columns
#
# `df.drop()` function is used to remove single or multiple rows and columns from the dataset DataFrame. It drops the specified labels from rows or columns.

# %%
df_copy = df.copy() #Create a copy of our dataset
print(df_copy.head())


#apply drop() method to remove the year column
df_copy = df_copy.drop(columns=['year'])  # Drops the 'year' column

print(df_copy.head())
# Out:
#           area  year  life_expectancy_at_birth
# 0  afghanistan  1800                 28.211000
# 1  afghanistan  1917                 27.012140
# 2  afghanistan  1918                  7.045063
# 3  afghanistan  1919                 26.991647
# 4  afghanistan  1950                 26.674000
#           area  life_expectancy_at_birth
# 0  afghanistan                 28.211000
# 1  afghanistan                 27.012140
# 2  afghanistan                  7.045063
# 3  afghanistan                 26.991647
# 4  afghanistan                 26.674000

# %% [markdown]
# ### 4.1.4. df.fillna(): Replace Null Values in DataFrame
#
# `df.fillna()` function allows you to replace null values (NaN/Na) in your dataset using a specified method or replacing null values with a specific value
#
# <br>
#
# Since, our current dataset those not have any null values, we will demonstrate this function using a simple example as shown in the code cell below.
#
# In the example, we fill missing SDG Index scores with the average of existing scores, and we fill missing Renewable Energy percentage with a specific value (the assumed global average, 26%).

# %%
import pandas as pd

# Create dictionary with data
data = {
    'Country': ['United States', 'China', 'India', 'Brazil'],
    'SDG Index Score (2022)': [80.0, None, 58.6, None],
    'Renewable Energy (%)': [12.7, 28.5, None, 46.0]
}

# Create DataFrame
df_1 = pd.DataFrame(data)

print("Original DataFrame")
print(df_1)


# Fill missing SDG Index scores with mean value
df_1['SDG Index Score (2022)'] = df_1['SDG Index Score (2022)'].fillna(df_1['SDG Index Score (2022)'].mean())

# Fill missing Renewable Energy with global average (26)
df_1['Renewable Energy (%)'] = df_1['Renewable Energy (%)'].fillna(26)

print("\nDataFrame after filling missing values")
print(df_1)
# Out:
# Original DataFrame
#          Country  SDG Index Score (2022)  Renewable Energy (%)
# 0  United States                    80.0                  12.7
# 1          China                     NaN                  28.5
# 2          India                    58.6                   NaN
# 3         Brazil                     NaN                  46.0
#
# DataFrame after filling missing values
#          Country  SDG Index Score (2022)  Renewable Energy (%)
# 0  United States                    80.0                  12.7
# 1          China                    69.3                  28.5
# 2          India                    58.6                  26.0
# 3         Brazil                    69.3                  46.0

# %% [markdown]
# **Additional Info: Missing Data Visualization**
#
# If a dataset is messy and contains many missing values, visualization is the fastest way to identify the status of the dataset. Missingno package provides easy-to-use function to quickly visual the summary of completeness of the dataset. For more information on how to use missingo package, here's a [link ](https://pypi.org/project/missingno/) to get you started

# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt

# Create a sample dataset with missing values
data = {
    'A': [1, 2, None, 4, 5],
    'B': [None, 2, 3, None, 5],
    'C': [1, 2, 3, 4, 5]
}

df_ms = pd.DataFrame(data)

# Visualize missing data using missingno
msno.matrix(df_ms)
plt.show()

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# **Prompt**
# ```
# Give an example that demonstrates how missingo package can be used to visualize missing data and null values in a dataset using various visualizations like heatmaps and bar plots.
# ```
#
#
# [ChatGPT Tutor Response](https://chat.openai.com/share/0966bf32-cee7-4226-be9a-0a3619d3020b)
#
# [Bard Tutor Response](https://g.co/bard/share/6705bcef34ea)
#
# <br>

# %% [markdown]
# ## 4.2 Handling Duplicate Data

# %% [markdown]
# The existence of duplicated values in a dataset is a critical aspect to consider during the Exploratory Data Analysis (EDA) process. Duplicate entries can significantly affect the integrity of the analysis by creating a false representation of the underlying data patterns, leading to biased or incorrect conclusions.
#
# Pandas provides two functions often used in tandem to check for the presence of duplicates and then drop them.

# %% [markdown]
# ### 4.2.1. df.duplicated(): Check for Duplicates
#
# This function returns a Boolean Series denoting duplicate rows. The Boolean series is True for every row of data that is a duplicate, and False otherwise. Here's an example using mini-version of our dataset:

# %%
# Create a dictionary of data
data1 = {
    'Area': ['United States', 'United States', 'India', 'India', 'Brazil', 'Brazil'],
    'Year': [2022, 2022, 2022, 2022, 2022, 2023],
    'Life Expectancy': [78.5, 78.5, 69.4, 69.4, 75.7, 75.8]
}

# Create a DataFrame from the dictionary
df_2 = pd.DataFrame(data1)


print("Original DataFrame")
print(df_2)


# making a bool series
bool_series = df_2.duplicated()

print("Boolean Series")
print(bool_series)


# Use duplicated() to check for duplicate rows
print("\nDuplicate Rows")
print(df_2[bool_series])
# Out:
# Original DataFrame
#             Area  Year  Life Expectancy
# 0  United States  2022             78.5
# 1  United States  2022             78.5
# 2          India  2022             69.4
# 3          India  2022             69.4
# 4         Brazil  2022             75.7
# 5         Brazil  2023             75.8
# Boolean Series
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool
#
# Duplicate Rows
#             Area  Year  Life Expectancy
# 1  United States  2022             78.5
# 3          India  2022             69.4

# %% [markdown]
# ### 4.2.2. drop_duplicates(): Drop Duplicates
#
# The df.drop_duplicates() function is used to remove duplicate rows from the DataFrame. By default, it keeps the first occurrence of the duplicate and removes the subsequent ones. However, you can specify whether to keep the first or last occurrence using the keep parameter.

# %%
# Use drop_duplicates() to drop the duplicate rows
df_dropped = df_2.drop_duplicates()

print("\nDataFrame after dropping duplicates")
print(df_dropped)
# Out:
# DataFrame after dropping duplicates
#             Area  Year  Life Expectancy
# 0  United States  2022             78.5
# 2          India  2022             69.4
# 4         Brazil  2022             75.7
# 5         Brazil  2023             75.8

# %% [markdown]
# ## 4.3. Data Transformation/Manipulation

# %% [markdown]
# After cleaning, handling missing values, and removing duplicates from the dataset, you now have better insights about the content and distribution of your data. However, your data might be in a format that is not suitable for the task you are dealing with. Hence, data transformation or manipulation operations are required.
#
# Let's see the suite of powerful functions offered by Pandas library that can help us at this stage of the EDA process to restructure, manipulate, and transform our data into suitable formats for further analysis.

# %% [markdown]
# ### 4.3.1. df.assign(): Adds New Columns to DataFrame
#
# The `df.assign()` new columns to the DataFrame and returns a new object with all original columns in addition to the new ones.

# %%
#combine area and year and add as a new column 'area_year'
df = df.assign(area_year = df['area'] + "_" + df['year'].astype(str))
print(df.head())
# Out:
#           area  year  life_expectancy_at_birth         area_year
# 0  afghanistan  1800                 28.211000  afghanistan_1800
# 1  afghanistan  1917                 27.012140  afghanistan_1917
# 2  afghanistan  1918                  7.045063  afghanistan_1918
# 3  afghanistan  1919                 26.991647  afghanistan_1919
# 4  afghanistan  1950                 26.674000  afghanistan_1950

# %% [markdown]
# ### 4.3.2. df.rename(): Alters axis labels.
#
# `df.rename()` allows you to change the names of the labels for your DataFrame's rows and/or columns.
#
# For example: If you want to rename the `life_expectancy_with_interpolations` column, you can do it as shown in the cell below. Also, `area` column label has been renamed.

# %%
df = df.rename(columns={"life_expectancy_at_birth": "Life Expectancy", "area": "Area"})
print(df.head())
# Out:
#           Area  year  Life Expectancy         area_year
# 0  afghanistan  1800        28.211000  afghanistan_1800
# 1  afghanistan  1917        27.012140  afghanistan_1917
# 2  afghanistan  1918         7.045063  afghanistan_1918
# 3  afghanistan  1919        26.991647  afghanistan_1919
# 4  afghanistan  1950        26.674000  afghanistan_1950

# %% [markdown]
# ### 4.3.3. df.apply(): Apply a Function along an Axis
#
# `df.apply()` permits you to apply a function along one of the axis of the DataFrame. That is, the function is applied to every element in the specified axis.
#
# For example, to convert each value of the 'Life Expectancy' column from years to months in our dataset, we can use the `df.apply()` function as shown in cell below:

# %%
# life expectancy is now in months
df['Life Expectancy'] = df['Life Expectancy'].apply(lambda x: x*12)
print(df.head())
# Out:
#           Area  year  Life Expectancy         area_year
# 0  afghanistan  1800       338.532000  afghanistan_1800
# 1  afghanistan  1917       324.145680  afghanistan_1917
# 2  afghanistan  1918        84.540753  afghanistan_1918
# 3  afghanistan  1919       323.899760  afghanistan_1919
# 4  afghanistan  1950       320.088000  afghanistan_1950

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# ```
# Given a dataset that consist of the life expectancy of countries in one of its columns. Can you give me a step-by-step breakdown of the code line below, which explains how lambda function is applied along the 'Life Expectancy' axis of the dataset to convert the life expectancy years to months?
#
# Code:
#
# df['Life Expectancy'].apply(lambda x: x*12)
# ```
#
# [ChatGPT Tutor Response](https://chat.openai.com/share/cd084867-c3ed-445c-a91d-0603a6993fa9)
#
# [Bard Tutor Response](https://g.co/bard/share/b5f4f3645f39)
#
# <br>

# %% [markdown]
# ### 4.3.4. df.astype(): Converting Columns from One Data Type to Another
#
# As we have introduced data types in chapter one, now it is time to know that the column type can be changed by the function `astype()`. You can choose to convert the original data type to other categories. When a dataframe size gets increased, the type of a column can affect the performance in calculation as it limits the size.
#
# `df.astype()` Casts a pandas object to a specified dtype.
#
# For example: We can convert years from integers to float datatype as shown in cell below:

# %%
# Data type of years before conversion
print(df['year'].dtype)

# Converts year to integer data type
df['year'] = df['year'].astype(float)

# Datatype of years after conversion
print(df['year'].dtype)
# Out:
# int64
# float64

# %% [markdown]
# Besides `astype()`function, here are three other functions to consider when converting types in pandas:
#
# - **to_numeric()** provides functionality to safely convert non-numeric types (e.g. strings) to a suitable numeric type.
#
# - **infer_objects()** a utility method to convert object columns holding Python objects to a pandas type if possible.
#
# - **convert_dtypes()** convert DataFrame columns to the "best possible" dtype that supports pd.NA.

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# ```
#
# Using the Pandas Dataframe function df.astypes(), give examples in python that demonstrate how this function can be used to convert data stored as a data frame from one datatype to another.  The examples, should cover every possible python Datatype.
# ```
#
# [ChatGPT Tutor Response](https://chat.openai.com/share/7517d178-f36b-4f49-a8f1-994d9dcd1d0b)
#
# [Bard Tutor Response](https://g.co/bard/share/c7e008489499)
#
# <br>

# %% [markdown]
# ### 4.3.5 df.tolist(): Convert DataFrame to a List
#
# Sometimes, we hope to convert the content from a dataset into a list for further manipulation. `tolist()` function is recommended for the purpose.

# %%
# tolist usage:
data_lst = df.values.tolist()
print(data_lst[:3]) #print the first three elements in the list
# Out:
# [['afghanistan', 1800, 28.211], ['afghanistan', 1917, 27.01213999999994], ['afghanistan', 1918, 7.045062710026063]]

# %% [markdown]
# ### 4.3.6. df.query(): Query DataFrame Columns
#
#  `df.query()` queries the columns of a DataFrame with a boolean expression.
#
# For example: In the example below, "Area == 'iceland'" is the boolean expression. It will be `True` for rows where the 'Area' is equal to 'iceland', and `False` otherwise.

# %%
print(df.query("Area == 'iceland'"))
# Out:
#           Area    year  Life Expectancy     area_year
# 13762  iceland  1735.0       467.483172  iceland_1735
# 13763  iceland  1736.0       526.183876  iceland_1736
# 13764  iceland  1737.0       469.856762  iceland_1737
# 13765  iceland  1738.0       416.477635  iceland_1738
# 13766  iceland  1739.0       323.051948  iceland_1739
# ...        ...     ...              ...           ...
# 14122  iceland  2095.0      1101.576000  iceland_2095
# 14123  iceland  2096.0      1102.872000  iceland_2096
# 14124  iceland  2097.0      1104.168000  iceland_2097
# 14125  iceland  2098.0      1105.440000  iceland_2098
# 14126  iceland  2099.0      1106.700000  iceland_2099
#
# [365 rows x 4 columns]

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# ```
#
# What other ways can we use the Pandas df.query() function with transforming and manipulating our dataset? For instance, df.query("Area == 'iceland'") has been used to identify all rows in a dataframe where area corresponds to 'iceland'. How else can this function help us in our EDA process?
# ```
#
# [ChatGPT Tutor Response](https://chat.openai.com/share/98e92787-9c9e-44b7-b2a3-d2cf5c47cdba)
#
# [Bard Tutor Response](https://g.co/bard/share/380b2dc4adac)
#
# <br>

# %% [markdown]
# ### 4.3.7. df.sort_values(): Sorts a DataFrame along either axis.

# %%
df = df.sort_values(by='Life Expectancy')
print(df.head())
# Out:
#                    Area    year  Life Expectancy              area_year
# 17125              fiji  1875.0        12.000000              fiji_1875
# 18477  french_polynesia  1918.0        12.000000  french_polynesia_1918
# 46120             samoa  1918.0        12.000000             samoa_1918
# 54984           tunisia  1819.0        18.000000           tunisia_1819
# 24022           iceland  1785.0        25.724735           iceland_1785

# %% [markdown]
# ### 4.3.8. df.sample(): Returns a random sample of items from an axis of object.

# %%
print(df.sample(n=10))
# Out:
#               Area    year  Life Expectancy         area_year
# 29373   kyrgyzstan  2036.0       846.636000   kyrgyzstan_2036
# 28780    korea_rep  2043.0      1052.172000    korea_rep_2043
# 6286       bolivia  2076.0       927.372000      bolivia_2076
# 33491     maldives  1954.0       400.260000     maldives_1954
# 34913    mauritius  1876.0       418.188917    mauritius_1876
# 31885  macao_china  1848.0       416.400000  macao_china_1848
# 24429        india  1892.0       271.857089        india_1892
# 13922    czech_rep  2062.0      1010.868000    czech_rep_2062
# 2512     australia  1902.0       611.818824    australia_1902
# 37869      namibia  1832.0       388.800000      namibia_1832

# %% [markdown]
# ### 4.3.9. df.merge():
#
# Allows you to join two dataframes together based on common columns
#
# The type of merge to be performed is specified using the how parameter.
#
# Here are the basic types of merges:
#
# * left: Use keys from the left frame only.
# * right: Use keys from the right frame only.
# * inner: Use intersection of keys from both frames.
# * outer: Use union of keys from both frames.
#
# Let's illustrate each merging method using dataframes with columns "area", "year", and "life_expectancy".

# %%
import pandas as pd

# Create two sample dataframes
df1 = pd.DataFrame({
    'area': ['Area1', 'Area2', 'Area3', 'Area4'],
    'year': [2001, 2002, 2003, 2004],
    'life_expectancy': [75, 78, 82, 85]
})

df2 = pd.DataFrame({
    'area': ['Area3', 'Area4', 'Area5', 'Area6'],
    'year': [2003, 2004, 2005, 2006],
    'life_expectancy': [83, 86, 79, 80]
})

print("DataFrame 1:")
print(df1)

print("\nDataFrame 2:")
print(df2)
# Out:
# DataFrame 1:
#     area  year  life_expectancy
# 0  Area1  2001               75
# 1  Area2  2002               78
# 2  Area3  2003               82
# 3  Area4  2004               85
#
# DataFrame 2:
#     area  year  life_expectancy
# 0  Area3  2003               83
# 1  Area4  2004               86
# 2  Area5  2005               79
# 3  Area6  2006               80

# %%
# Left Merge

left_merge = df1.merge(df2, on=['area', 'year'], how='left', suffixes=('_df1', '_df2'))
print(left_merge)
# Out:
#     area  year  life_expectancy_df1  life_expectancy_df2
# 0  Area1  2001                   75                  NaN
# 1  Area2  2002                   78                  NaN
# 2  Area3  2003                   82                 83.0
# 3  Area4  2004                   85                 86.0

# %%
# Right Merge

right_merge = df1.merge(df2, on=['area', 'year'], how='right', suffixes=('_df1', '_df2'))
print(right_merge)
# Out:
#     area  year  life_expectancy_df1  life_expectancy_df2
# 0  Area3  2003                 82.0                   83
# 1  Area4  2004                 85.0                   86
# 2  Area5  2005                  NaN                   79
# 3  Area6  2006                  NaN                   80

# %%
# Inner Merge

inner_merge = df1.merge(df2, on=['area', 'year'], how='inner', suffixes=('_df1', '_df2'))
print(inner_merge)
# Out:
#     area  year  life_expectancy_df1  life_expectancy_df2
# 0  Area3  2003                   82                   83
# 1  Area4  2004                   85                   86

# %%
# Outer Merge:
outer_merge = df1.merge(df2, on=['area', 'year'], how='outer', suffixes=('_df1', '_df2'))
print(outer_merge)
# Out:
#     area  year  life_expectancy_df1  life_expectancy_df2
# 0  Area1  2001                 75.0                  NaN
# 1  Area2  2002                 78.0                  NaN
# 2  Area3  2003                 82.0                 83.0
# 3  Area4  2004                 85.0                 86.0
# 4  Area5  2005                  NaN                 79.0
# 5  Area6  2006                  NaN                 80.0

# %% [markdown]
# ### 4.3.10 Filtering <a class="anchor" id="three-one-four"></a>
#
# **Filter based on a condition**
#
# **Example:** Return rows where life expectancy is greater than 76.

# %%
df = df.rename(columns={"Life Expectancy" :"life_expectancy_at_birth" , "Area": "area"})

# %%
filtered_df = df[df['life_expectancy_at_birth'] > 76]

filtered_df
# Out:
#            area  year  life_expectancy_at_birth
# 154       aland  1997                    78.900
# 155       aland  1998                    81.000
# 156       aland  1999                    78.250
# 157       aland  2000                    80.000
# 158       aland  2001                    80.830
# ...         ...   ...                       ...
# 35190  zimbabwe  2095                    80.468
# 35191  zimbabwe  2096                    80.617
# 35192  zimbabwe  2097                    80.765
# 35193  zimbabwe  2098                    80.911
# 35194  zimbabwe  2099                    81.056
#
# [12319 rows x 3 columns]

# %% [markdown]
# **Filter based on multiple conditions**
#
# **Example:** Return rows for zimbabwe from the year 2010.

# %%
filtered_df = df[(df['area'] == 'zimbabwe') & (df['year'] > 2010)]

filtered_df
# Out:
#            area  year  life_expectancy_at_birth
# 35106  zimbabwe  2011                    56.040
# 35107  zimbabwe  2012                    58.142
# 35108  zimbabwe  2013                    59.871
# 35109  zimbabwe  2014                    61.165
# 35110  zimbabwe  2015                    62.017
# ...         ...   ...                       ...
# 35190  zimbabwe  2095                    80.468
# 35191  zimbabwe  2096                    80.617
# 35192  zimbabwe  2097                    80.765
# 35193  zimbabwe  2098                    80.911
# 35194  zimbabwe  2099                    81.056
#
# [89 rows x 3 columns]

# %% [markdown]
# ### 4.3.11 Grouping <a class="anchor" id="three-one-four"></a>
#
# **Group by a single column**
#
# **Example:** Group data by area and calculate the average life expectancy.

# %%
grouped = df.groupby('area').life_expectancy_at_birth.mean()
grouped
# Out:
# area
# afghanistan           57.643019
# aland                 80.139000
# albania               73.826996
# algeria               56.676384
# angola                53.931008
#                         ...
# west_bank_and_gaza    70.724496
# western_sahara        63.609314
# yemen_rep             58.862048
# zambia                59.709469
# zimbabwe              63.155138
# Name: life_expectancy_at_birth, Length: 204, dtype: float64

# %% [markdown]
# **Group by multiple columns**
#
# **Example:** Group data by area and year and get the sum of life expectancy.

# %%
grouped = df.groupby(['area', 'year']).life_expectancy_at_birth.sum()
grouped
# Out:
# area         year
# afghanistan  1800    28.211000
#              1917    27.012140
#              1918     7.045063
#              1919    26.991647
#              1950    26.674000
#                        ...
# zimbabwe     2095    80.468000
#              2096    80.617000
#              2097    80.765000
#              2098    80.911000
#              2099    81.056000
# Name: life_expectancy_at_birth, Length: 35195, dtype: float64

# %% [markdown]
# ### 4.3.12 Pandas Time Series and Date Functionality <a class="anchor" id="three-one-four"></a>

# %% [markdown]
# To handle time series data using pandas, first, we read sample dataset:

# %%
import pandas as pd

# Read and preprocess air_quality data
air_quality = pd.read_csv(
    "https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_no2_long.csv",
    index_col=0, on_bad_lines='skip'
)
air_quality = air_quality.rename(columns={"date.utc": "datetime"})

# Display first few rows
air_quality.head()
# Out:
# <ipython-input-39-564c05ca6651>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   air_quality = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_no2_long.csv",index_col=0,error_bad_lines=False)
#       country                   datetime location parameter  value   unit
# city
# Paris      FR  2019-06-21 00:00:00+00:00  FR04014       no2   20.0  µg/m³
# Paris      FR  2019-06-20 23:00:00+00:00  FR04014       no2   21.8  µg/m³
# Paris      FR  2019-06-20 22:00:00+00:00  FR04014       no2   26.5  µg/m³
# Paris      FR  2019-06-20 21:00:00+00:00  FR04014       no2   24.9  µg/m³
# Paris      FR  2019-06-20 20:00:00+00:00  FR04014       no2   21.4  µg/m³

# %% [markdown]
# Using the <b>pd.to_datetime()</b> function, we can convert dates in text form to datetime:

# %%
air_quality["datetime"] = pd.to_datetime(air_quality["datetime"])

air_quality["datetime"]
# Out:
# city
# Paris    2019-06-21 00:00:00+00:00
# Paris    2019-06-20 23:00:00+00:00
# Paris    2019-06-20 22:00:00+00:00
# Paris    2019-06-20 21:00:00+00:00
# Paris    2019-06-20 20:00:00+00:00
#                     ...
# London   2019-05-07 06:00:00+00:00
# London   2019-05-07 04:00:00+00:00
# London   2019-05-07 03:00:00+00:00
# London   2019-05-07 02:00:00+00:00
# London   2019-05-07 01:00:00+00:00
# Name: datetime, Length: 2068, dtype: datetime64[ns, UTC]

# %% [markdown]
# With the <b>max()</b> and <b>min()</b> functions, we can find the largest and smallest dates in the column, as well as <b>subtract</b> and <b>add</b>:

# %%
air_quality["datetime"].max() - air_quality["datetime"].min()

# %% [markdown]
# With the <b>dt</b>  accessor, we can access the properties of the dates such as <b>month, year, day, quarter etc.</b>:

# %%
air_quality["month"] = air_quality["datetime"].dt.month
air_quality["year"] = air_quality["datetime"].dt.year
air_quality["quarter"] = air_quality["datetime"].dt.quarter
air_quality["day"] = air_quality["datetime"].dt.day
air_quality["hour"] = air_quality["datetime"].dt.hour
air_quality["minute"] = air_quality["datetime"].dt.minute
air_quality["second"] = air_quality["datetime"].dt.second
air_quality.head()

# %% [markdown]
# We can create pivot table and while doing this we can create <b>index</b> with datetime:

# %%
no_2 = air_quality.pivot(index="datetime", columns="location", values="value")

no_2.head()

# %% [markdown]
# When the datetime is in the index, you can access the properties with the index instead of dt accessor:

# %%
no_2.index.year, no_2.index.weekday, no_2.index.month, no_2.index.day, no_2.index.hour, no_2.index.minute, no_2.index.second

# %% [markdown]
# We can change the frequency of the table using <b>resample()</b>:

# %%
monthly_max = no_2.resample("M").max()

monthly_max

# %% [markdown]
# ### 4.3.12 Export Dataframe to a CSV File
#
# **to_csv()** function is used to export a DataFrame from pandas in Python to a CSV file.
#
# For example: After performing the relevant data cleaning and exploratory analysis, we can save our dataset as csv as seen below:

# %%
# Export dataframe to a CSV file
df.to_csv('modified_life_expectancy.csv', index=False)

# %% [markdown]
# ## 5. Outlier Detection and Treatment
#
# An outlier is data that **differ significantly** from the other observations. As a result, distribution is found to be highly skewed because of the outliers, which can have harmful consequences on later use of the data, in Machine Learning, for example.
# <br> Noticing and cleaning them is therefore an important part of the data exploration process.
#
# **What cause an outlier?**
#
# Outliers can indicate 2 things:
# - The outliers can be due to a measurement error, such as a typo or a malfunction in the measurement tool. These should be cautiously discarded from the dataset!
# - The outliers can result from a highly skewed (asymmetric) distribution or a heavy-tailed distribution. These situations can occur in non-normal distributions, such as exponential, geometric, Poisson, or bimodal distributions
#
# *Assuming we are in normal distribution we mainly focus on the first case scenario and the dataset need to be cleaned up*
#
# **How to detect an outlier?**
# - Thanks to data visualization, we can easily identify outlier candidate as they stand far from the rest of the data point. However, this is not sufficient to just eyeball them, we need to test if an observation is indeed an outlier or not.
#
# <br>There exist multiple mathematical methods to identify outliers:
# - A data point can be defined as an outlier if its **distance to the mean is superior to 3 times the standard deviation**. Or in other term, when a data point **Z score** is > 3, it is considered an outlier.
# Where:
#
# <br><center>$Z score = (X - {\mu}) / {\sigma}$
# - Similarly to the previous method, you may have heard of the 1.5 IQR method, which stands for 1.5 times the interquartile range (the range between the first quartile and the third quartile). This methodology yields similar results to the previous method, as 1.5 IQR is roughly equivalent to 3 standard deviations.
#
# <br><center> Lower bound: $ Q1 - 1.5 * IQR$
# <center> Upper bound: $ Q3 - 1.5 * IQR$
#
# <br> - There exist more complex test that can attest outliers, like for example: the **[Local outlier method](https://scikit-learn.org/stable/auto_examples/neighbors/plot_lof_outlier_detection.html#:~:text=The%20Local%20Outlier%20Factor%20(LOF,lower%20density%20than%20their%20neighbors.)** or the **[Minimum covariance determinant](https://scikit-learn.org/stable/modules/generated/sklearn.covariance.MinCovDet.html)**.

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# ```
# What are outliers in a dataset? What are the sources or root causes of outliers in a dataset.   What are the available tools for detecting outliers in data. For each of the three questions, respond with details and if possible examples to enhance understanding.
# ```
#
# * [ChatGPT Tutor Response](https://chat.openai.com/share/a0807f09-8817-453d-8406-ec9f271a285f)
#
# * Copy and past the prompt above in your  [BARD](https://bard.google.com/) interface to see the response of BARD machine tutor.
#
# <br>

# %% [markdown]
# ### 5.1. Normal (Gaussian) Distribution
#
# The [normal distribution](https://www.investopedia.com/terms/n/normaldistribution.asp#:~:text=Investopedia%20%2F%20Lara%20Antal-,What%20Is%20a%20Normal%20Distribution%3F,as%20a%20%22bell%20curve%22) is a symmetric probability distribution in which the majority of the observations are grouped around the distribution's **mean**, or center peak.
# <br>
# <br> The likelihood of values occurring close to the mean is larger than the likelihood of values happening far from the mean. (e.g: Marks of students in a class (Mean = 60, SD = 20))
#
# <br>
# <br> A normal curve, also known as the bell  (see image below), is the graph of the probability density function of the normal distribution, representing the probabilities of different outcomes in a continuous dataset.It has two parameters:
# 1.	mean μ (center of the curve) (can be any real number)
# 2.	standard deviation σ (spread about the center, must be greater than 0)
# <br>
# <br>The normal curve, also known as the bell curve, is the graph of the probability density function of the normal distribution, representing the probabilities of different outcomes in a continuous dataset.
#
# <p align="center">
#   <img src="https://miro.medium.com/max/640/1*aDfLhLY1zMVcK4Ax8nTROg.png" />
# </p>
# <br> -  Approximately 68.2% of all of the points are within the range -1 to 1 standard deviation.
# <br> -  About 95.5% of all of the points are within the range -2 to 2 standard deviations.
# <br> -  About 99.7% of all of the points are within the range -3 to 3 standard deviations.
#
# For more information on normal distribution, check out these links:
# * [Normal distribution - Wikipedia](https://en.wikipedia.org/wiki/Normal_distribution)
# * [Normal Distribution Explained with Python Examples](https://vitalflux.com/normal-distribution-explained-python-examples/)
#
# <br>

# %% [markdown]
# ### **Why do we need normally distributed data ?**
#
# The world of machine learning and data science revolves around the concepts of probability distributions.  Many machine learning algorithms perceive data as normal so it is important to feed it with normal or normalized data. Once we are aware of the distribution of the values, we can begin calculating the probabilities of events, even with the aid of formulas. As a result, we can start to comprehend our target variables' behavior better.
# <br>
# Check the links below for more in depth understanding of the importance of having a normally distributed dataset:
# * [Ever Wondered Why Normal Distribution Is So Important?](https://medium.com/fintechexplained/ever-wondered-why-normal-distribution-is-so-important-110a482abee3)
#
# * [Modelling the probability distributions of dice](https://towardsdatascience.com/modelling-the-probability-distributions-of-dice-b6ecf87b24ea)
# <p align="center">
#   <img src="https://miro.medium.com/max/1400/1*q_v7LYQXg-qQtroBbuBunA.gif"width="400" />
# </p>
#
# **How to test for normality?**
#
# 1. **Histograms**: Should be a bell curve.
# 2. **QQ Plot**: it allows us to see deviation of a normal distribution much better than in a Histogram or Box Plot. The data should follow the line and should be a curve.
# 3. **Kolmogorov & Smirnov test**: If techniques below are not conclusive;
# <br>If the observed data perfectly follow a normal distribution, the value of the KS statistic will be 0.
# <br>The P-Value is used to decide whether the difference is large enough to reject the null hypothesis:
#
# - If the P-Value of the KS Test is larger than 0.05, we assume a normal distribution.
# - If the P-Value of the KS Test is smaller than 0.05, we do not assume a normal distribution.
# 4. **Shapiro & Wilk**: It has been developed specifically for the normal distribution and it cannot be used for testing against other distributions like for example the KS test.
#
# - If the P-Value of the Shapiro Wilk Test is larger than 0.05, we assume a normal distribution.
# - If the P-Value of the Shapiro Wilk Test is smaller than 0.05, we do not assume a normal distribution.
# <br>It will return the test statistic called W and the P-Value.
# <br> Attention: for ***N > 5000*** the W test statistic is accurate but the p-value may not be.
#
# ##### How to fix non - normal data ?
#
# 1. **Boxcox Transformation** : scipy.stats.boxcox(x, lambda=None, alpha=None)

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# ```
# What are outliers in a dataset? What are the sources or root causes of outliers in a dataset.   What are the available tools for detecting outliers in data. For each of the three questions, respond with details and if possible examples to enhance understanding.
# ```
#
# * [ChatGPT Tutor Response](https://chat.openai.com/share/a0807f09-8817-453d-8406-ec9f271a285f)
#
# * Copy and past the prompt above in your  [BARD](https://bard.google.com/) interface to see the response of BARD machine tutor.
#
#
# <br>

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# ```
# Should data we are dealing with in a data science project  always be normally distributed? If yes, why? and if no, why not?
# ```
#
# [ChatGPT Tutor Response](https://chat.openai.com/share/d364cc86-bb74-40fb-ae13-a52cb5887ebc)
#
# [Bard Tutor Response](https://g.co/bard/share/48c4ef09683a)
#
# <br>

# %% [markdown]
# The following code shows how to plot multiple normal distribution curves with different means and standard deviations. We might use either **numpy.random.normal** or might import **norm** from **scipy.stats** to visualize normal distribution from randomly generated data.
#
# > **Note:** Do not fret if you do not understand the code used to generate the visualization via Matplotlib and other libraries. In the upcoming section, you will learn how to visualize your dataset using this library.

# %%
#Plotting normal data with different standard deviations
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

#x-axis ranges from -5 and 5 with .001 steps
x = np.arange(-5, 5, 0.001)

#define multiple normal distributions
plt.plot(x, norm.pdf(x, 0, 1), label='mean: 0, STD: 1')
plt.plot(x, norm.pdf(x, 0, 1.5), label='mean:0, STD: 1.5')
plt.plot(x, norm.pdf(x, 0, 2), label='mean:0, STD: 2')

#add legend to plot
plt.legend()

# %%
from scipy.stats import norm
import scipy.integrate as integrate

mean = 0
distribution_function = lambda x: norm.pdf(x, mean)
x1 = -1
x2 = 1

print('probability to fall between {0} and {1} :'.format(x1, x2), integrate.quad(distribution_function, x1, x2)[0])
step = 0.001
whole_x = np.arange(-4, 4, step)
whole_y = distribution_function(whole_x)

needed_x = np.arange(x1, x2, step)
needed_y = distribution_function(needed_x)
plt.plot(whole_x, whole_y)
plt.fill_between(needed_x, needed_y, color='pink')
plt.show()

#probability to fall between -1 and 1 : 0.682689492137086
#meaning there is a 68.2% chance that the value of the variable
#will be within -1 and 1 . (-1, 1 standard deviations, first)
# Out:
# probability to fall between -1 and 1 : 0.682689492137086

# %% [markdown]
# For more information on CIs (Confidence Intervals) : https://www.youtube.com/watch?v=w3tM-PMThXk

# %%
# Kolmogorov & Smirnov
from scipy.stats import kstest, norm
my_data = norm.rvs(size=1000)
ks_statistic, p_value = kstest(my_data, 'norm')
print(ks_statistic, p_value)
# Out:
# 0.02044276378484089 0.7894779254167943

# %%
# Shapiro & Wilk
from scipy import stats
rng = np.random.default_rng()
x = stats.norm.rvs(loc=5, scale=3, size=100, random_state=rng)
shapiro_test = stats.shapiro(x)
shapiro_test
shapiro_test.statistic
0.9813305735588074
shapiro_test.pvalue
0.16855233907699585
# Out:
# 0.16855233907699585

# %%
# QQ Plot
import statsmodels.api as sm
from scipy.stats import norm
import pylab

my_data = norm.rvs(size=100)
sm.qqplot(my_data, line='45')
pylab.show()

# %%
# Box-cox Transformation of non-normal data to normal data

import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# Generate non-normal data (exponential)
original_data = np.random.exponential(size=1000)

# Transform training data & save lambda value
fitted_data, fitted_lambda = stats.boxcox(original_data)

# Creating axes to draw plots
fig, ax = plt.subplots(1, 2)

# Plotting the original data (non-normal) and fitted data (normal)
sns.kdeplot(original_data, fill=True, linewidth=2, label="Non-Normal", color="green", ax=ax[0])
sns.kdeplot(fitted_data, fill=True, linewidth=2, label="Normal", color="green", ax=ax[1])

# Adding legends to the subplots
plt.legend(loc="upper right")

# Rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)

print(f"Lambda value used for Transformation: {fitted_lambda}")
# Out:
# <ipython-input-71-fe2b53045acf>:22: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(original_data, hist = False, kde = True,
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2511: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <ipython-input-71-fe2b53045acf>:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %% [markdown]
# **What are the consequences of outliers?**
#
# As we said, outliers can be harmful for data centric project:
#
# * By skewing the distribution it affects any statistical and analytical tools and can lead to erroneous interpretation or results.
# * Training a machine learning project on a dataset presenting outliers is harmful. Simply because in its way to generalize a pattern, the regression will take into account wrong and extreme outliers, resulting in a poorer fit and lower predictive performances.
#
# For those reasons, It is important to assess the data distribution and to spot outliers by analyzing, plotting and testing the data.

# %% [markdown]
# # 6. Data Visualization for EDA <a class="anchor" id="four"></a>

# %% [markdown]
# Data visualization, using tools such as Matplotlib and Seaborn, is a fundamental aspect of the exploratory data analysis (EDA) process. By translating our dataset from abstract numeric values into intuitive graphical representations, we can better understand the intricacies and complexities of the dataset we are dealing with. It gives us an added visual dimension. That is, an alternative approach to analysing our dataset.
#
# <br> Such visualizations can expose patterns, trends, correlations, outliers, and structure of the data that may not be apparent from looking at raw data tables or simple statistics. They offer a way to quickly grasp the data, making it easier to convey insights and even tell stories.
#
# As mentioned earlier in this notebook, Matplotlib and Seaborn are the two main visualization tools we are going to use to explore our data further.

# %% [markdown]
# ## 6.1 Basic Plots
#
# In the realm of data visualization, several basic plot types serve as the foundation for understanding data patterns and trends. The most fundamental plot types are Bar Plots, Line Plots, Scatter Plots, and Histograms. Each of these plots has a unique purpose and is best suited for specific kinds of data and analysis, as you will see below:
#
# Let's begin by using the Matplotlib library to create these basic plots, as it is the most commonly used library, particularly for generating simpler visualizations

# %% [markdown]
# ### 6.1.1 Histogram Charts
#
# Histograms are a graphical display of frequencies. They are represented as bars. They show what portion of the dataset falls into each category, usually specified as non-overlapping intervals. These categories are called bins. The .hist() method would help us to create a simple histogram.
#
# To begin plotting our histogram using Matplotlib, we first of all need to import the package as indicated in the cell below. Then, call the hist() method on our data

# %%
# Import Matplotlib
import matplotlib.pyplot as plt

data1 = np.random.randn(1000) #A sample generation based on random

plt.hist(data1)
plt.xlabel("x")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### 6.1.2 Bar charts
#
# Bar charts display rectangular bars either in vertical or horizontal form. Their length is proportional to the values they represent. They are used to compare two or more values. The `.bar()` method would be used to create a bar graph.

# %%
data2 = [5. , 25. , 50. , 20.]

plt.bar(range(len(data2)), data2)
plt.xlabel("x")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### 6.1.3. Scatter Plot
#
# Another commonly used plot type is the scatter plot. Here the points are represented individually with a dot or a circle. The `.scatter()` method would help to create a scatter plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='sin(x)', color='blue', linewidth=2, linestyle='-', marker='o', markersize=6, markerfacecolor='red', markeredgewidth=2, markeredgecolor='black')

# Title
plt.title('Sine Function')  # Sets the title of the plot

plt.xlabel('x')
plt.ylabel('sin(x)')

# Customizing Tick Marks
plt.xticks(np.arange(0, 11, step=1))  # Set tick marks on the x-axis from 0 to 10
plt.yticks(np.arange(-1, 1.5, step=0.5))  # Set tick marks on the y-axis from -1 to 1.5

# Grid
plt.grid(True, linestyle='--', alpha=0.7)  # Add grid lines with dashed lines and transparency

# Legend
plt.legend(loc='upper right')  # Add a legend at the upper right corner

plt.savefig('sin_plot.png')
plt.show()

# %% [markdown]
# ### 6.1.4. Pie Charts
#
# Pie charts are circular representations divided into sectors. The sectors are also called wedges. The `pie()` function is used to plot pie charts from an array X. Wedges are created proportionally, so that each value x of array X generates a wedge proportional to x/sum(X).

# %%
labels = 'Health', 'Climate Change', 'Obesity'
sizes = [70.4, 20.6, 9.0]
colors = ['lightgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, shadow=True, startangle=90)
plt.title("What is the most concerning topic for the next 10 years?(100 people)")
plt.legend(title="Answers")
plt.axis('equal')
plt.show()

# %% [markdown]
# **Bonus Tip:** Pandas provides an alternative approach to plotting these simple figures directly without having to import matplotlib. Let me show you how

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# ```
# How can we use matplotlib library to visualize our dataset in a data science project. Use a simple dataset and basic plots such as bar charts, histograms, Pie charts, scatter plots and any other basic plots to demonstrate this in a clear and easy to understand format.
# ```
#
# [ChatGPT Tutor Response](https://chat.openai.com/share/5ebb2bce-66af-4c7f-824e-e049784321d7)
#
# [Bard Tutor Response](https://g.co/bard/share/bdfb9e781991)
#
# <br>

# %% [markdown]
# ## 6.2 Data Visualization using Pandas package

# %% [markdown]
# Pandas package allows us to use several visualization techniques with its available tools. Although it is not a data visualization library, it is quite useful and practical to explore the data by creating visualizations and plots. Pandas library provides various functions with the help of
#  .plot() function. Lİne plot, bar plot, histogram plot, box plot, area plot, scatter plot, pie chart can be created by using pandas library.

# %% [markdown]
# ### 6.2.1 Scatter Plot
# DataFrame.plot.scatter() function is used while creating scatter plots. Scatter plot takes two arguments to lot the graph (eg. x, y). This function also enables giving names to the values of x and y-axis as the name of columns.

# %%
# I have used the sample dataset from Python documentation created in 3.2.2

import pandas as pd

df = pd.DataFrame({'num_legs': [2, 4, 8, 0],
                   'num_wings': [2, 0, 0, 0],
                   'num_specimen_seen': [10, 2, 1, 8],
                   "species":['falcon', 'dog', 'spider', 'fish']})

df.plot.scatter(x='species', y='num_legs')  #scatter plot between species and number of legs
# Out:
# <Axes: xlabel='species', ylabel='num_legs'>

# %% [markdown]
# ### 6.2.2 Pie Chart
# `DataFrame.plot.pie()` function or Series.plot.pie() are used to creating pie charts. For the data frame, it generates individuals pies for each column in the data frame in the form of subplots.

# %%
# I have created a new data set for pie chart

import numpy as np

my_df = pd.DataFrame(np.random.rand(6, 3),
                   columns=('Column_1', 'Column_2', 'Column_3'))

my_df.plot.pie(subplots=True ,figsize=(15, 15))
# Out:
# array([<Axes: ylabel='Column_1'>, <Axes: ylabel='Column_2'>,
#        <Axes: ylabel='Column_3'>], dtype=object)

# %% [markdown]
# ### 6.2.3 Histogram
# `DataFrame.plot.hist()` function is used while creating histograms.

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## 6.3 Subplots <a class="anchor" id="four-three"></a>
#
# It's a common scenario in data analysis where we desire to display multiple plots simultaneously for comparative or holistic examination. Let's delve into how we can accomplish this task in Python using Pandas

# %%
# suppose we are ploting 2 plots together
# 1. create the empty canvas for the plots
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('two subplots')

# 2. plot the two scatter subplots
x=np.linspace(0,100,30)
y=np.random.rand(30)
ax1.plot(x, y)
ax2.plot(x, -y)

# %% [markdown]
# ## 6.4 Additional Data Visualizations (Complex Plots) <a class="anchor" id="four-four"></a>
#
# Other than plotting the data directly, we can also use popular statistical methods to analyse our dataset. Here we briefly demonstrate the application of Kernel Density Estimation plots (KDE plots) and correlation graphs to extract information regarding your features.
#
# ### 6.4.1 Kernel Density Plot  <a class="anchor" id="four-four-one"></a>
#
# Kernel Density Estimation (KDE) is a method used to estimate the probability density function of a numerical variable, using a kernel function. We encourage the reader to dive deeper into the mathematical definitions and examples provided [here](https://machinelearningmastery.com/probability-density-estimation/), [here](https://www.statsmodels.org/stable/examples/notebooks/generated/kernel_density.html) and the [Wikipedia Article](https://en.wikipedia.org/wiki/Kernel_density_estimation). However, for now, it suffices that one can learn to read and interpret KDE plots, as the mathematical ground is well-established and several python libraries provide the output required.

# %% [markdown]
# KDE plots use a kernel, a mathematical function, to estimate the probability that a given value appears in the random variable being analyzed. Depending on the data being analyzed, different kernels and smoothing parameters should be chosen. Similar to histograms, the quality of the representation also depends on selecting appropriate smoothing parameters. For further guidance on KDE parameters and how to properly represent the data, refer to the Seaborn documentation. [here](https://seaborn.pydata.org/generated/seaborn.kdeplot.html).
#
# As summary, KDE plots can be helpful to:
# * See variable value range, i.e. min, max, mean
# * See most common values in our data (peaks)
# * Understand if our data is representative of all use cases we might be interested in, i.e. one may notice, by the peaks and valleys, that not enough samples of a particular value range were collected
# * For classification problems, it is interesting to see how the variable curve shape might change according to the class
# * Variables that do not present a Gaussian-like distribution (i.e. Heavy-Tailed) might need to through some kind of transformation (log or power transform) to improve model performance
#
# For plotting the KDE visual, let's switch from Matplotlib library to the powerful **Seaborn** library. The KDE plot will be done over the Iris dataset which has four features: *Sepal Length, Sepal Width, Petal Length and Petal Width*. More information regarding the Iris dataset can be found [here](https://archive.ics.uci.edu/ml/datasets/iris).

# %% [markdown]
# <p align="center">
#   <img src="https://github.com/SDG-AI-Lab/dashboard_images/blob/main/seaborn.png?raw=true" />
# </p>

# %%
#let's use seaborn visualisation library
import seaborn as sns

# %%
#load iris dataset
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize=(20,5))#set figure size
ax = sns.kdeplot(data = iris) #plot definition
plt.title('KDE Plot Iris Dataset');  #set title name

#remove spines just to look better
sns.despine(top=True, right=True, left=False, bottom=False)

# %% [markdown]
# From the above plot, we can extract the following insights:
# * The bell shape of Sepal Width peaks around 3 (x-axis). The peak represents the variable mean value and it is also the value with highest probability. We can also see that for this feature the values range from approximately 2 and do not go beyond 4
# * The red and green curves have more than one peak. For the Petal Width, it gives us the indication of the two different widths (the two peaks) that are the most common in our data.
# * Similar case for the green curve regarding its bimodal shape. Also, the Petal Length (green) curve spreads across the whole x-axis. This variable contains values of a wider range compared to the other variables
# * Lastly, the blue curve has a different shape. While the mean is still at the middle of this curve, this type of flat peak indicates that the values have the same probability of occurring.

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# ```
# I want you to act as a data visualization expert. Using the Seaborn library, and a simple dataset, create basic histogram, bar chart, pie chart, and scatter plots to illustrate how a learner can visualize data.
# ```
#
# * [ChatGPT Tutor Response](https://chat.openai.com/share/a6f48a01-507a-4441-bf8f-7bca9512c36f)
#
# * Copy and paste the prompt above in your  [BARD](https://bard.google.com/) interface to see the response of BARD machine tutor.
#
# <br>

# %% [markdown]
# ### 6.4.1 Plotly Library  <a class="anchor" id="four-five"></a>
# In addition to the plotting techniques and libraries illustrated above, you can create interactive data visualizations using the Plotly library.
#
# Plotly's Python graphing library creates interactive, publication-quality graphs. Here are examples of how to make line plots, scatter plots, area charts, bar charts, error bars, box plots, histograms, heatmaps, subplots, multiple axes, polar charts, and bubble charts.
#
# Plotly.py is free and open-source, and you can view the source, report issues, or contribute on GitHub.
#
# Plotly Express is the easy-to-use, high-level interface to Plotly, which works with a variety of data types and produces easy-to-style figures.
#
# In the next sections, we will show how to create different chart types using Plotly.

# %% [markdown]
# **Scatter Plot <a class="anchor" id="four-five-one"></a>**
# With px.scatter, each data point is represented as a marker point, whose location is given by the x and y columns.

# %%
# x and y given as DataFrame columns
import plotly.express as px
df = px.data.iris() # iris is a pandas DataFrame
figure = px.scatter(df, x="sepal_width", y="sepal_length")
figure.show()

# %% [markdown]
# Scatter plots with variable-sized circular markers are often known as bubble charts. Note that color and size data are added to hover information.
# You can add other columns to hover data with the hover_data argument of px.scatter.

# %%
import plotly.express as px
df = px.data.iris()
figure = px.scatter(df, x="sepal_width", y="sepal_length", color="species",
                 size='petal_length', hover_data=['petal_width'])
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Scatter plots support faceting. Facet plots, also known as trellis plots or small multiples, are figures made up of multiple subplots which have the same set of axes, where each subplot shows a subset of the data.

# %%
import plotly.express as px
df = px.data.tips()
figure = px.scatter(df, x="total_bill", y="tip", color="smoker", facet_col="sex", facet_row="time")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Statistical Charts<a class="anchor" id="four-five-two"></a>**
#
# Plotly also supports the creation of statistical charts, like error bars, histograms, and tree plots.
#
# We will cover histograms in this section.
#
# In statistics, a histogram is a representation of the distribution of numerical data, where the data are binned, and the count for each bin is represented. More generally, in Plotly, a histogram is an aggregated bar chart, with several possible aggregation functions (e.g., sum, average, count, etc.) that can be used to visualize data on categorical, date, and linear axes.

# %%
import plotly.express as px
df = px.data.tips()
figure = px.histogram(df, x="total_bill")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Plotly histograms will automatically bin numerical or date data but can also be used on raw categorical data, as in the following example, where the X-axis value is the categorical "day" variabl

# %%
import plotly.express as px
df = px.data.tips()
figure = px.histogram(df, x="day", category_orders=dict(day=["Thur", "Fri", "Sat", "Sun"]))
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Scientific Charts<a class="anchor" id="four-five-three"></a>**
#
#  You can also visualize data in scientific charts like log plots, heatmaps and contour plots.

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007")

figure = px.scatter(df, x="gdpPercap", y="lifeExp", hover_name="country",
                 log_x=True, range_x=[1,100000], range_y=[0,100])
figure.show()

# %% [markdown]
# ## 7. Correlation and Covariance Analysis

# %% [markdown]
# Correlation and covariance are powerful statistical concepts used to measure the relationship between two or more variables.

# %% [markdown]
# ### 7.1 Correlation Analysis and Visualization  <a class="anchor" id="four-four-one"></a>
#
# A correlation coefficient (commonly represented by *r*) is a value that describes the strength of the linear relationship between two variables. A common method to measure correlation is the [Pearson correlation coefficient](https://www.statisticshowto.com/probability-and-statistics/correlation-coefficient-formula/#Pearson). The output is a value that can range from +1 to -1, representing the correlation between two features of our data. If two variables have a high correlation value, it means that both variables are "moving" in the same direction, i.e., they change together at a constant rate. For example, if one variable increases its value, the other also increases. Negative values represent variables moving in the opposite direction, i.e., they are inversely correlated. A value of r = 0 indicates no correlation (the variables are independent).
#
# **What can we learn from the Correlation Heatmap?**
# * For regression problems, variables with a high correlation (positive or negative) to the target value are usually important features for your dataset. In short, this means that when this feature increases, your target value will likely exhibit the same behavior.
#
# * Correlation analysis can help identify non-relevant features or reduce the number of variables. For example, when two variables are highly correlated, they might be providing similar information to your model. In such cases, one of them can be removed to reduce the complexity of your data.
#
# **What we should not assume from the Correlation Heatmap?**
#
# * Variables that have values close to +1 and -1 present a **linear** relationship. When the correlation coefficient is close to 0, it does not mean that there is not some type of relationship there. It simply means that the relationship might be of another form (exponential, quadratic or something else). Use scatter plots to visualise the relationship between variables as well
#
# * Correlation does not imply causation. From the correlation analysis, we cannot assume cause-and-effect between two variables. Using an example from the [Wikipedia](https://en.wikipedia.org/wiki/Correlation_does_not_imply_causation) article, let's say you analysing a study that highly correlates time watching TV and the level of aggressiveness in children. One could assume "Children that watch a lot of TV are the most violent. TV makes children more violent." However, this could be the other way round; that is, violent children like watching more TV than less violent ones.
#
# Correlation is usually plotted in the form of a heatmap. The heatmap will have the maximum values on its diagonal, as it is the relationship between the variable and itself. As such, for the analysis, we only consider half the heatmap. Below we plot the correlation output of the iris dataset, using the command **.corr()** and the Seaborn library.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# Load the iris dataset as a DataFrame
iris_data = load_iris(as_frame=True)
iris = iris_data.frame

# Drop the non-numeric column ('target' is the species column in sklearn's iris dataset)
numeric_iris = iris.drop(columns=["target"])

# Calculate the correlation matrix
corr = numeric_iris.corr()

# Plot the heatmap
ax = sns.heatmap(corr, linewidths=.5, annot=True, fmt=".2f", cbar=False)
plt.show()
# Out:
# <ipython-input-80-644cf1074a4a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = iris.corr() #creates a matrix with the correlation values of numerical variables

# %% [markdown]
# From the above plot, we can extract the following insights:
# * Sepal Length seems to increase with Petal Length (0.87) and Petal Width (0.82). However, the Sepal Width is not strongly correlated (-0.12) to the Sepal Length
# * Sepal Width is inversely correlated to Petal Length and Petal Width. One can think of this as: the larger the flower Sepal Width, it might present smaller Petal Lengths and Widths
# * Petal Length and Width are highly correlated, close to 1. As such, increase in Petal Length is usually also reflected in an increase in Petal Width
#
# For brevity, not all visualisations tools were demonstrated here (e.g. violin and box-plots). However, it gives the initial tools to start your data analysis and exploration journey.

# %% [markdown]
# ## 7.2 Covariance
#
# Covariance is a measure of how much two random variables vary together. It's used to gauge the linear degree of change between two variables, to see how much one can be predicted from the other. The sign of the covariance shows the tendency in the linear relationship between the variables:
#
# Positive covariance: Indicates that two variables tend to move in the same direction.
# Negative covariance: Reveals that two variables tend to move in inverse directions.
#
# The example code cell shows how to compute covariance with the iris dataset and visualization using seaborn heatmap

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the iris dataset from seaborn
iris = sns.load_dataset("iris")

# Exclude the non-numeric 'species' column
numeric_iris = iris.drop(columns=["species"])

# Compute the covariance matrix
covariance_matrix = numeric_iris.cov()

# Display the covariance matrix
print(covariance_matrix)

# Create a heatmap from the covariance matrix
plt.figure(figsize=(10, 8))
sns.heatmap(covariance_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title("Covariance Matrix Heatmap")
plt.show()
# Out:
# <ipython-input-83-4a42bb0f32b1>:9: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   covariance_matrix = iris.cov()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006

# %% [markdown]
# ### 🤖 Machine Tutor Question
#
# Copy and paste the prompt below in your [ChatGPT](https://chat.openai.com/) and [BARD](https://bard.google.com/) interface to see the response of BARD machine tutor.
#
# ```
# Can you explain correlation and covariance and their relevance within the context of data exploration in machine learning?
# ```
#
# <br>

# %% [markdown]
# # Conclusion
#
# Congratulations on successfully navigating through this comprehensive course on Exploratory Data Analysis (EDA)! From understanding the fundamental Python libraries like pandas, NumPy, Matplotlib, and Seaborn to delving into the intricacies of data exploration, data cleaning, descriptive statistics, and understanding correlation and covariance, we've covered a vast landscape of knowledge and skills.
#
# Here's a brief recap of what you've learned:
#
# * **Introduction to Python Libraries for EDA:** The foundations to equip you with essential tools for EDA.
# * **Loading and Exploring Data:** Grasping the Pandas DataFrame and Series and how to inspect data.
# * **Descriptive Statistics with Pandas:** Engaging in statistical analysis to describe the central tendency and variability.
# * **Data Cleaning:** Scrubbing and tidying the dataset, removing unnecessary noise.
# * **Understanding Correlation and Covariance:** Building a nuanced understanding of the relationships between variables.
#
# These skills form the bedrock of modern data science and are applicable across a multitude of domains and industries.
#
# As you close this chapter of the Data Science for Sustainable Development, it's time to move on to the next exciting one. So, what comes next? You've learned how to explore and understand data, but where does this data come from? That's precisely what you'll learn in our next course titled "Data and Data Collection."
#
# In the upcoming course, we'll explore the different sources of data, methods of data collection, and the ethics surrounding it. You'll learn about the critical starting point of every data science project – acquiring the right data in the right way.
#
# Once again, congratulations on completing this course, and thank you for your dedication and hard work. See you in the next course!

# %% [markdown]
# # Reference <a class="anchor" id="reference"></a>
#
# - [Exploratory Data Analysis; A Practical Guide and Template for Structured Data](https://towardsdatascience.com/exploratory-data-analysis-eda-a-practical-guide-and-template-for-structured-data-abfbf3ee3bd9) by Jiahao Weng
# - [Matplotlib tutorial for beginners](https://www.kaggle.com/prashant111/matplotlib-tutorial-for-beginners) by Prashant Banerjee
# - [Learn basics of data visualization](https://www.kaggle.com/learn/data-visualization) by Kaggle Tutorials
# - [Plotly Open Source Graphing Libraries](https://plotly.com/graphing-libraries/)
